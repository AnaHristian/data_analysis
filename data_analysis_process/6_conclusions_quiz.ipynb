# %% [markdown]
# # Drawing Conclusions Quiz
# Use the space below to explore `store_data.csv` to answer the quiz questions below.

# %%
# imports and load data
import pandas as pd
import matplotlib.pyplot as plt
% matplotlib inline

# %%
df = pd.read_csv('store_data.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 6 columns):
# week      200 non-null object
# storeA    200 non-null int64
# storeB    200 non-null int64
# storeC    200 non-null int64
# storeD    200 non-null int64
# storeE    200 non-null int64
# dtypes: int64(5), object(1)
# memory usage: 8.6+ KB

# %%
df.head()
# Out:
#          week  storeA  storeB  storeC  storeD  storeE
# 0  2014-05-04    2643    8257    3893    6231    1294
# 1  2014-05-11    6444    5736    5634    7092    2907
# 2  2014-05-18    9646    2552    4253    5447    4736
# 3  2014-05-25    5960   10740    8264    6063     949
# 4  2014-06-01    7412    7374    3208    3985    3023

# %%
df.describe()
# Out:
#              storeA        storeB       storeC       storeD       storeE
# count    200.000000    200.000000   200.000000   200.000000   200.000000
# mean    5865.480000   6756.710000  4942.105000  5431.405000  2580.025000
# std     2958.230318   3601.339489  1325.407768  1183.111323  1725.651381
# min      137.000000     14.000000   927.000000  2276.000000    39.000000
# 25%     3812.250000   3884.500000  4053.500000  4717.000000  1235.000000
# 50%     5713.500000   6771.000000  4962.500000  5382.000000  2522.000000
# 75%     7662.250000   9350.500000  5801.750000  6243.750000  3574.250000
# max    14403.000000  15841.000000  8293.000000  8190.000000  7553.000000

# %%
df.tail()
# Out:
#            week  storeA  storeB  storeC  storeD  storeE
# 195  2018-01-28     282    6351    7759    5558    1028
# 196  2018-02-04    4853    6503    4187    5956    1458
# 197  2018-02-11    9202    3677    4540    6186     243
# 198  2018-02-18    3512    7511    4151    5596    3501
# 199  2018-02-25    7560    6904    3569    5045    2585

# %%
df[196:]
# Out:
#            week  storeA  storeB  storeC  storeD  storeE
# 196  2018-02-04    4853    6503    4187    5956    1458
# 197  2018-02-11    9202    3677    4540    6186     243
# 198  2018-02-18    3512    7511    4151    5596    3501
# 199  2018-02-25    7560    6904    3569    5045    2585

# %%
df.hist(figsize=(8,8));

# %%
df_last_month = df[196:]
df_last_month
# Out:
#            week  storeA  storeB  storeC  storeD  storeE
# 196  2018-02-04    4853    6503    4187    5956    1458
# 197  2018-02-11    9202    3677    4540    6186     243
# 198  2018-02-18    3512    7511    4151    5596    3501
# 199  2018-02-25    7560    6904    3569    5045    2585

# %%
print(sum(df_last_month['storeA']))
print(sum(df_last_month['storeB']))
print(sum(df_last_month['storeC']))
print(sum(df_last_month['storeD']))
print(sum(df_last_month['storeE']))
df_last_month.sum()
# Out:
# 25127
# 24595
# 16447
# 22783
# 7787
# week      2018-02-042018-02-112018-02-182018-02-25
# storeA                                       25127
# storeB                                       24595
# storeC                                       16447
# storeD                                       22783
# storeE                                        7787
# dtype: object

# %%
# total sales for the last month
df.iloc[196:,1:].sum()
# Out:
# storeA    25127
# storeB    24595
# storeC    16447
# storeD    22783
# storeE     7787
# dtype: int64

# %%
# average sales
df.mean()
# Out:
# week      (1.28998911693832e-233+1.2900874010687383e-233j)
# storeA                             (5865.4800000000005+0j)
# storeB                                        (6756.71+0j)
# storeC                             (4942.1050000000005+0j)
# storeD                                       (5431.405+0j)
# storeE                                       (2580.025+0j)
# dtype: complex128

# %%
df.head()
# Out:
#          week  storeA  storeB  storeC  storeD  storeE
# 0  2014-05-04    2643    8257    3893    6231    1294
# 1  2014-05-11    6444    5736    5634    7092    2907
# 2  2014-05-18    9646    2552    4253    5447    4736
# 3  2014-05-25    5960   10740    8264    6063     949
# 4  2014-06-01    7412    7374    3208    3985    3023

# %%
# sales on march 13, 2016
df[df['week'] == '2016-03-13']
# Out:
#           week  storeA  storeB  storeC  storeD  storeE
# 97  2016-03-13    2054    1390    5112    5513    2536

# %%
df.describe()
# Out:
#              storeA        storeB       storeC       storeD       storeE
# count    200.000000    200.000000   200.000000   200.000000   200.000000
# mean    5865.480000   6756.710000  4942.105000  5431.405000  2580.025000
# std     2958.230318   3601.339489  1325.407768  1183.111323  1725.651381
# min      137.000000     14.000000   927.000000  2276.000000    39.000000
# 25%     3812.250000   3884.500000  4053.500000  4717.000000  1235.000000
# 50%     5713.500000   6771.000000  4962.500000  5382.000000  2522.000000
# 75%     7662.250000   9350.500000  5801.750000  6243.750000  3574.250000
# max    14403.000000  15841.000000  8293.000000  8190.000000  7553.000000

# %%
df[df['storeC'] == 927]
# Out:
#          week  storeA  storeB  storeC  storeD  storeE
# 9  2014-07-06    8567    3228     927    3277     168

# %%
# worst week for store C
df[df['storeC'] == df['storeC'].min()]
# Out:
#         week  storeA  storeB  storeC  storeD  storeE
# 9 2014-07-06    8567    3228     927    3277     168

# %%
df.head(20)
# Out:
#          week  storeA  storeB  storeC  storeD  storeE
# 0  2014-05-04    2643    8257    3893    6231    1294
# 1  2014-05-11    6444    5736    5634    7092    2907
# 2  2014-05-18    9646    2552    4253    5447    4736
# 3  2014-05-25    5960   10740    8264    6063     949
# 4  2014-06-01    7412    7374    3208    3985    3023
# 5  2014-06-08    1289   10137    5070    7163    1703
# 6  2014-06-15    6282    3925    5528    4748    3351
# 7  2014-06-22    5135    7317    5530    4595     104
# 8  2014-06-29   11766   12560    3199    4676    3573
# 9  2014-07-06    8567    3228     927    3277     168
# 10 2014-07-13    3123    6129    4518    4891    4598
# 11 2014-07-20    5299    5456    2104    3889    2429
# 12 2014-07-27   14403      14    5146    6982    2032
# 13 2014-08-03   10400    3488    7993    7837     984
# 14 2014-08-10    5715   13234    2476    5265    4900
# 15 2014-08-17   11043    5181    5292    6660    3473
# ...

# %%
# total sales during most recent 3 month period
last_three_months = df[df['week'] >= '2017-12-01']
last_three_months.iloc[:,1:].sum()  # exclude sum of week column
# Out:
# storeA    87591
# storeB    79394
# storeC    66538
# storeD    75190
# storeE    27334
# dtype: int64
